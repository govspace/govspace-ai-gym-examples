# %% [markdown]
# # 📝 Template Notebook
#
# Use this notebook as a starting point for your own analysis or demos.
#
# Sections included:
# - Markdown for explanations
# - Code cells for analysis
# - Visualization placeholders

# %% [markdown]
# ## 1️⃣ Introduction
# Write a short description of your project or dataset here.

# %%
# Example: import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2️⃣ Load Data
# Add your dataset loading code here.

# %%
# Example: create a tiny DataFrame
df = pd.DataFrame({
    'Category': ['A', 'B', 'C'],
    'Value': [10, 20, 15]
})
df

# %% [markdown]
# ## 3️⃣ Analysis / Visualization
# Add plots or computations here.

# %%
sns.barplot(data=df, x='Category', y='Value')
plt.title('Template Bar Plot')
plt.show()

# %% [markdown]
# ## 4️⃣ Next Steps
# - Replace this template with your dataset
# - Add more analysis cells
# - Save results or export plots
